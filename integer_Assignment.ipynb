# %%
print("SOLVED EXAMPLE")
print("calculate the sum of first 5 even numbers")
first_5_even=[2,4,6,8,10]
sum_even=sum(first_5_even)
print(f"Frist 5 evennumbers:{first_5_even}")
print(f"Sum:{sum_even}")
print("-"* 50)
# Out:
# SOLVED EXAMPLE
# calculate the sum of first 5 even numbers
# Frist 5 evennumbers:[2, 4, 6, 8, 10]
# Sum:30
# --------------------------------------------------

# %%
# Out:
#   Cell In[7], line 2
#     print(number)type
#                  ^
# SyntaxError: invalid syntax

# %%
# Question: Calculate the area of a circle with radius 5.5
print("SOLVED EXAMPLE:")
print("Calculate the area of a circle with radius 5.5")
import math
radius = 5.5
area = math.pi * radius ** 2
print(f"Radius: {radius}")
print(f"Area: {area:.2f}")
print("-" * 50)

# ASSIGNMENT QUESTIONS
# ===================
# Out:
# SOLVED EXAMPLE:
# Calculate the area of a circle with radius 5.5
# Radius: 5.5
# Area: 95.03
# --------------------------------------------------

# %%
# Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577
print("Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577")

num=[3.14,2.718,1.618,0.577]
length=len(num)
total=sum(num)/length
print(f"total Average: {total:.4f}")
# Out:
# Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577
# total Average: 2.0133

# %%
# Question 2: Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)
print("Question 2: Convert 98.6 Fahrenheit to Celsius")
fahrenheit=98.6
convert_celsius=(5/9)*(fahrenheit-32)
print(convert_celsius)
# Out:
# Question 2: Convert 98.6 Fahrenheit to Celsius
# 37.0

# %%
# Question 3: Calculate the compound interest on $1000 at 5.5% for 3 years
print("Question 3: Calculate compound interest on $1000 at 5.5% for 3 years")

intial_in=1000
rate=5.5
time=3
total_amount=(intial_in)*(1+rate/100)**3
total_amount
cI=total_amount-intial_in
print(f"Compound interest: {cI:.3f}")
# Out:
# Question 3: Calculate compound interest on $1000 at 5.5% for 3 years
# Compound interest: 174.241

# %%
# Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2
print("Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2")
a=3.5
b=4.2
#Square_root=a**2+b**2
#ypotenuse=(Square_root)**2
#rint(f"hypotenuse of a right triangle: {Square_root:.3f}")
print(round(math.sqrt(a**2 + b**2),2))
# Out:
# Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2
# 5.47

# %%
# Question 5: Calculate the volume of a sphere with radius 7.8
print("Question 5: Calculate the volume of a sphere with radius 7.8")
# formula v=4\3*3.14*r***3
radius=7.8
volume=(4/3)*3.14*(radius**3)
print(round(volume,2))
# Out:
# Question 5: Calculate the volume of a sphere with radius 7.8
# 1986.79

# %%
# Question 6: Round 3.14159 to 3 decimal places
print("Question 6: Round 3.14159 to 3 decimal places")
decimal_num=3.14159

print(round(decimal_num,2))
print(f"two decimal: {decimal_num:.2f}")
# Out:
# Question 6: Round 3.14159 to 3 decimal places
# 3.14
# two decimal: 3.14

# %%
# Question 8: Find the square root of 23.456
print("Question 8: Find the square root of 23.456")
import math
decimal_num=23.456
print(math.sqrt(decimal_num))
# Out:
# Question 8: Find the square root of 23.456
# 4.843139477652899

# %%
# Question 7: Calculate the percentage: 45 out of 67
print("\nQuestion 7: Calculate the percentage: 45 out of 67")
num = 45
den = 67
percentage = (num / den) * 100
print(round(percentage,2))
# Out:
# Question 7: Calculate the percentage: 45 out of 67
# 67.16

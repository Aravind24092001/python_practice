# %%
# Question 1: Create a dictionary of student names and their ages
print("Question 1: Create a dictionary of student names and their ages")

dict1={'Name':'Sai', 'age':25}
dict1
# Out:
# Question 1: Create a dictionary of student names and their ages
# {'Name': 'Sai', 'age': 25}

# %%
dict1['Name']='Aravind'
dict1
# Out:
# {'Name': 'Aravind', 'age': 25}

# %%
# Question 2: Add a new key-value pair to dictionary {'a': 1, 'b': 2, 'c': 3}
print("Question 2: Add a new key-value pair to dictionary {'a': 1, 'b': 2, 'c': 3}")

dict1['a']=1
dict1['b']=2
dict1['c']=3
dict1
# Out:
# Question 2: Add a new key-value pair to dictionary {'a': 1, 'b': 2, 'c': 3}
# {'Name': 'Aravind', 'age': 25, 'a': 1, 'b': 2, 'c': 3}

# %%
# Question 3: Get all keys from dictionary {'name': 'John', 'age': 25, 'city': 'New York'}
print("Question 3: Get all keys from dictionary {'name': 'John', 'age': 25, 'city': 'New York'}")

dict1={'name': 'John', 'age': 25, 'city': 'New York'}
# Out:
# Question 3: Get all keys from dictionary {'name': 'John', 'age': 25, 'city': 'New York'}

# %%
dict_keys=dict1.keys()
dict_keys
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
# Question 4: Get all values from dictionary {'python': 3, 'java': 2, 'c++': 1}
print("Question 4: Get all values from dictionary {'python': 3, 'java': 2, 'c++': 1}")

dict1={'python': 3, 'java': 2, 'c++': 1}
# Out:
# Question 4: Get all values from dictionary {'python': 3, 'java': 2, 'c++': 1}

# %%
dict_keys=dict1.values()
dict_keys
# Out:
# dict_values([3, 2, 1])

# %%
# Question 5: Check if key 'age' exists in {'name': 'Alice', 'age': 30, 'city': 'London'}
print("Question 5: Check if key 'age' exists in {'name': 'Alice', 'age': 30, 'city': 'London'}")

dict1={'name': 'Alice', 'age': 30, 'city': 'London'}
dict_exists='age' in dict1
dict_exists
# Out:
# Question 5: Check if key 'age' exists in {'name': 'Alice', 'age': 30, 'city': 'London'}
# True

# %%
# Question 6: Remove key 'temp' from {'a': 1, 'b': 2, 'temp': 3, 'c': 4}
print("question 6: Remove key 'temp' from {'a': 1, 'b': 2, 'temp': 3, 'c': 4}")

dict1={'a': 1, 'b': 2, 'temp': 3, 'c': 4}
dict_keys=dict1.pop("temp")
print(dict_keys)
dict1
# Out:
# question 6: Remove key 'temp' from {'a': 1, 'b': 2, 'temp': 3, 'c': 4}
# 3
# {'a': 1, 'b': 2, 'c': 4}

# %%
# Question 7: Find the sum of all values in {'math': 85, 'science': 92, 'english': 78}
print("Question 7: Find the sum of all values in {'math': 85, 'science': 92, 'english': 78}")

dict1={'math': 85, 'science': 92, 'english': 78}
sum=0
for i in dict1:
       sum=sum+dict1[i]
print(f"sum of the values {sum}")
# Out:
# Question 7: Find the sum of all values in {'math': 85, 'science': 92, 'english': 78}
# sum of the values 255

# %%
# Question 8: Create a dictionary with squares of numbers 1 to 5
print("Question 8: Create a dictionary with squares of numbers 1 to 5")

squares={x:x**2 for x in range(1,6)}
print(squares)
# Out:
# Question 8: Create a dictionary with squares of numbers 1 to 5
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# Question 9: Count frequency of each character in string "hello"
print("Question 9: Count frequency of each character in string 'hello'")

s1="hello"
freq1={}

for ch in s1:
    freq1[ch]=freq1.get(ch,0)+1
print(freq1)
# Out:
# Question 9: Count frequency of each character in string 'hello'
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
# Question 10: Merge two dictionaries {'a': 1, 'b': 2} and {'c': 3, 'd': 4}
print("Question 10: Merge two dictionaries {'a': 1, 'b': 2} and {'c': 3, 'd': 4}")

dict1={'a': 1, 'b': 2}
dict2={'c': 3, 'd': 4}

merged=dict1 | dict2
print(f"merged two dict {merged}")
# Out:
# Question 10: Merge two dictionaries {'a': 1, 'b': 2} and {'c': 3, 'd': 4}
# merged two dict {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# Question 11: Create a nested dictionary: {'person': {'name': 'Alice', 'age': 25}}
print("Question 11: Create a nested dictionary: {'person': {'name': 'Alice', 'age': 25}}")

dictionary= {
    'person':
       {
          'name': 'Alice',
            'age': 25
       }
    }
print(dictionary)
# Out:
# Question 11: Create a nested dictionary: {'person': {'name': 'Alice', 'age': 25}}
# {'person': {'name': 'Alice', 'age': 25}}

# %%
# Question 12: Access nested value 'name' from {'person': {'name': 'Alice', 'age': 25}}
print("Question 12: Access nested value 'name' from {'person': {'name': 'Alice', 'age': 25}}")

dictionary={
    'person':
       {
          'name': 'Alice',
            'age': 25
       }
    }
dict1=dictionary['person']['name']
print(dict1)
# Out:
# Question 12: Access nested value 'name' from {'person': {'name': 'Alice', 'age': 25}}
# Alice

# %%
# Question 13: Create a dictionary with list values: {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}
print("Question 13: Create a dictionary with list values: {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}")

dict1={
    'fruits':['apple', 'banana'],
      'colors': ['red', 'blue']}
print(dict1)
# Out:
# Question 13: Create a dictionary with list values: {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}
# {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}

# %%
# Question 14: Add 'orange' to the 'fruits' list in nested dictionary
print("Question 14: Add 'orange' to the 'fruits' list in nested dictionary")

dict1['fruits'].append('orange')
print(dict1)
# Out:
# Question 14: Add 'orange' to the 'fruits' list in nested dictionary
# {'fruits': ['apple', 'banana', 'orange', 'orange'], 'colors': ['red', 'blue']}

# %%
# Question 15: Create a dictionary with tuple values: {'coordinates': (10, 20), 'rgb': (255, 0, 0)}
print("Question 15: Create a dictionary with tuple values: {'coordinates': (10, 20), 'rgb': (255, 0, 0)}")

dict1={'coordinates': (10, 20), 'rgb': (255, 0, 0)}
print(f"create a tuple in dict1 '{dict1}' ")
# Out:
# Question 15: Create a dictionary with tuple values: {'coordinates': (10, 20), 'rgb': (255, 0, 0)}
# create a tuple in dict1 '{'coordinates': (10, 20), 'rgb': (255, 0, 0)}'

# %%
# Question 16: Extract first coordinate from nested tuple
print("Question 16: Extract first coordinate from nested tuple")

dict_extract=dict1['coordinates']
print(dict_extract)
# Out:
# Question 16: Extract first coordinate from nested tuple
# (10, 20)

# %%
# Question 17: Create a dictionary with set values: {'vowels': {'a', 'e', 'i'}, 'consonants': {'b', 'c', 'd'}}
print("Question 17: Create a dictionary with set values: {'vowels': {'a', 'e', 'i'}, 'consonants': {'b', 'c', 'd'}}")

dict1={
    'vowels': {'a', 'e', 'i'},
      'consonants': {'b', 'c', 'd'}
      }
print(f"create a set in dict'{dict1}'")
print(type(dict1))
# Out:
# Question 17: Create a dictionary with set values: {'vowels': {'a', 'e', 'i'}, 'consonants': {'b', 'c', 'd'}}
# create a set in dict'{'vowels': {'i', 'e', 'a'}, 'consonants': {'c', 'b', 'd'}}'
# <class 'dict'>

# %%
print("Question 18: Add 'o' to vowels set in nested dictionary")

dict1['vowels']=['i','e','o','u']

print(dict1)
# Out:
# Question 18: Add 'o' to vowels set in nested dictionary
# {'vowels': ['i', 'e', 'o', 'u'], 'consonants': {'c', 'b', 'd'}}

# %%
# Question 19: Create a 3-level nested dictionary: {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}
print("Question 19: Create a 3-level nested dictionary: {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}")

dict1={'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}
print(dict1)
# Out:
# Question 19: Create a 3-level nested dictionary: {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}
# {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}

# %%
print("Question 21: Create a dictionary with mixed data types: {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}")

dict_mixed={'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}
print(dict_mixed)
# Out:
# Question 21: Create a dictionary with mixed data types: {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}
# {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}

# %%
print("Question 22: Check data type of each value in mixed dictionary")

for key in dict_mixed:
    value = dict_mixed[key]
    print(f"{key}: {value} -> {type(value)}")
# Out:
# Question 22: Check data type of each value in mixed dictionary
# int: 42 -> <class 'int'>
# float: 3.14 -> <class 'float'>
# str: hello -> <class 'str'>
# bool: True -> <class 'bool'>

# %%
print("Question 23: Create a dictionary with function values: {'len': len, 'str': str, 'int': int}")

dict1={'len': len, 'str': str, 'int': int}
print(dict1)
# Out:
# Question 23: Create a dictionary with function values: {'len': len, 'str': str, 'int': int}
# {'len': <built-in function len>, 'str': <class 'str'>, 'int': <class 'int'>}

# %%
print("Question 25: Create a dictionary with lambda functions: {'double': lambda x: x*2, 'square': lambda x: x**2}")

dict1={'double': lambda x: x*2, 'square': lambda x: x**2}
print(dict1)
# Out:
# Question 25: Create a dictionary with lambda functions: {'double': lambda x: x*2, 'square': lambda x: x**2}
# {'double': <function <lambda> at 0x00000261CB6F76A0>, 'square': <function <lambda> at 0x00000261CB6F4720>}

# %%
print("question 26: Apply each lambda function to 5")

for name, func in dict1.items():
    print(f"{name}(5) = {func(5)}")
# Out:
# question 26: Apply each lambda function to 5
# double(5) = 10
# square(5) = 25

# %%
print("Question 27: Create a dictionary with class values: {'list': list, 'dict': dict, 'set': set}")

dict1={'list': list, 'dict': dict, 'set': set}

for i in dict1:
    values = dict1[i]   # Access the value by key
    print(f"{i}: {values}")
# Out:
# Question 27: Create a dictionary with class values: {'list': list, 'dict': dict, 'set': set}
# list: <class 'list'>
# dict: <class 'dict'>
# set: <class 'set'>

# %%
print("Question 28: Create instances using class dictionary")

# %%
print("Question 29: Create a dictionary with None values: {'a': None, 'b': None, 'c': None}")

dict1={'a': None, 'b': None, 'c': None}
print(dict1)
# Out:
# Question 29: Create a dictionary with None values: {'a': None, 'b': None, 'c': None}
# {'a': None, 'b': None, 'c': None}

# %%
# Question 30: Replace all None values with 0
print("Question 30: Replace all None values with 0")

dict1 = {k: (0 if v is None else v) for k, v in dict1.items()}
# Out:
# Question 30: Replace all None values with 0

# %%
# Exercise 1: Simple Age Check Write a program that checks if a person can get a driver's license (age >= 16).
print("Write a program that checks if a person can get a driver's license (age >= 16)")

age=24
if age>=16:
    print(f"get lisence")
else:
    print(f"Your are not eligible to get a lisence")
    print(f"under a age  lesser than 16 ")
# Out:
# Write a program that checks if a person can get a driver's license (age >= 16)
# get lisence

# %%
# Exercise 2: Positive or Negative Write a program that checks if a number is positive, negative, or zero.
print("Write a program that checks if a number is positive, negative, or zero.")

number=float(input("enter the number"))

if number>=0:
    if number>0:
        print(f"Its a positive number")
    else:
        print(f"Its a  Zero number")
else:
    print(f"its a nagetive number")
# Out:
# Write a program that checks if a number is positive, negative, or zero.
# Its a positive number

# %%
#Exercise 3: Larger Number Write a program that compares two numbers and prints which one is larger.
print("Write a program that compares two numbers and prints which one is larger.")

a=20
b=30
if a>=b:
    print(f"'{a}'a is a larger")
else:
    print(f"'{b}' b is a larger ")
# Out:
# Write a program that compares two numbers and prints which one is larger.
# '30' b is a larger

# %%
#Exercise 4: Calculator Discount A store offers:
#10% discount if purchase > $100
#5% discount if purchase > $50
#No discount otherwise
#Please enter the purchase amount: 200
#The final price after discount is: $180.00


amount=int(input("enter the amount"))

if amount>100:
    discount=0.10*amount
    final_price=amount-discount
    print(f"10% discount ")
    print(discount)
    print(f"final amount: {final_price}")
elif amount>50:
    discount=0.05*amount
    final_price=amount-discount
    print(f"discount : '{discount}'")
    print(f"5% discount")
    print(f"final amount: {final_price}")
else:
    print(f"no discount")
    print(f"final price: {amount}")
# Out:
# 10% discount
# 15.0
# final amount: 135.0

# %%
# question 5 :Leap Year Checker Write a program to check if a year is a leap year:
# Divisible by 4 AND (not divisible by 100 OR divisible by 400)
year = int(input("enter a year:"))
if year % 4 == 0 and (year % 100 !=0 or year % 400 ==0):
    print("leap year")
else:
    print("not a leap year")

# %%
#Login System with Attempts Create a login system that:Checks username and password Tracks login attempts (max 3) Locks account after failed attempts
correct_username = "admin"
correct_password = "1234"

attempts = 0
max_attempts = 3

while attempts < max_attempts:
    username = input("enter username")
    password = input("enter password")

    if username == correct_username and password == correct_password:
        print("login success")
        break
    else:
        attempts += 1
        print("wrong attempt, attempt left: ",max_attempts - attempts)
    
if attempts==max_attempts:
    print("many attempts!!")
# Out:
# wrong attempt, attempt left:  2
# wrong attempt, attempt left:  1
# wrong attempt, attempt left:  0
# many attempts!!

# %%
#Create a variable password_correct = True.
#If it is True, print "Access Granted", else print "Access Denied"

create_bool=True

if create_bool==True:
    print("true variable")
else:
    print("false variable")
# Out:
# true variable

# %%
#Write a program that checks if a character is a vowel.
s = 'a'
vowels = "aeiouAEIOU"
found = False

for v in vowels:
    if s == v:
        print("Character is a vowel")
        found =True
        break 

if not found:
    print("Character is not a vowel")
# Out:
# Character is a vowel

# %%
name="hello world"
print(name)
# Out:
# hello world

# %%
tech_stack="Azure Devops and python and sql and"
first_ampresand=tech_stack.replace("and","&",1)
first_ampresand
# Out:
# 'Azure Devops & python and sql and'

# %%
course_slogan="learn data engineering with real-time project"
course_slogan.replace(" ","")
# Out:
# 'learndataengineeringwithreal-timeproject'

# %%
text="Python python pYthon"
text.replace("Python","     ").upper()
# Out:
# '      PYTHON PYTHON'

# %%
name1="  name **"
name2="name **"
name3=" name**"
name4="name**"
name5="name**"

# %%
name4==name5
# Out:
# True

# %%
user_input= " data science"

# %%
institute="edukron"
focus_area="Data Science"
full_tittle=institute +": "+ focus_area
print(f"1.full title: {full_tittle}")
# Out:
# 1.full title: edukron: Data Science

# %%
separator="-*="*10
print(f"2. welcome: {separator}")
# Out:
# 2. welcome: -*=-*=-*=-*=-*=-*=-*=-*=-*=-*=

# %%
keyword=" python "
emphasized=keyword*3
print(f"4.emphasized keyword:{emphasized}")
# Out:
# 4.emphasized keyword: python  python  python

# %%
base_path="/courses/"
course_id="DA101"
full_path=base_path+course_id
print(f"5.simple path:{full_path}")
# Out:
# 5.simple path:/courses/DA101

# %%
message="Alert! "
no_alerts=message*0
print(f"10.repeating zero times:'{no_alerts}' ")
# Out:
# 10.repeating zero times:''

# %%
course_id="/data_science/"
modifications=(course_id).strip("/")
print(modifications)
# Out:
# data_science

# %%
group="  aptitude secssion "
new_group=(group).strip()
new_group
# Out:
# 'aptitude secssion'

# %%
new_group=(group).lstrip()
new_group
new_group=(group).rstrip()
new_group
# Out:
# '  aptitude secssion'

# %%
course_name="learn python and sql and data science and pyspark"
skills=(course_name).replace("and","&")
skills

skills=(course_name).replace("data science","data engineering")
skills
# Out:
# 'learn python and sql and data engineering and pyspark'

# %%
public_stand="here only standing purporse they kept stairs"
new_rule=(public_stand).index("o")
new_rule
# Out:
# 5

# %%
public_stand="here only standing purporse they kept stairs"
new_rule=public_stand.find("onlx")
new_rule
# Out:
# -1

# %%
cricket="match is going india and newzealand"
wicket=cricket.index("india")
wicket
# Out:
# 15

# %%
wicket=cricket.endswith("land")
wicket
# Out:
# True

# %%
name=input("enter the self intro")
len(name)
# Out:
# 7

# %%
course="Python and Sql and Data Sciene"
print(course.upper())
print(course.lower())
# Out:
# PYTHON AND SQL AND DATA SCIENE
# python and sql and data sciene

# %%
course_slogan="learn data engineering with real-time project"
vowels=course_slogan.startswith("l")
vowels
# Out:
# True

# %%
course_slogan="Engineering"
course=course_slogan[2:8:]
print(course)
#course_slogan==course
# Out:
# gineer

# %%
course_slogan="learn data engineering with real-time project"
new_course=course_slogan.split()
new_course
# Out:
# ['learn', 'data', 'engineering', 'with', 'real-time', 'project']

# %%
strip_sentence="  Is this using in function for doing some program and all the thing "
using_strip=strip_sentence.lstrip()
print(using_strip)
# Out:
# Is this using in function for doing some program and all the thing

# %%
strip_sentence="  Is this using in function for doing some program and all the thing "
new_split=strip_sentence.rsplit()
print(new_split)
# Out:
# ['Is', 'this', 'using', 'in', 'function', 'for', 'doing', 'some', 'program', 'and', 'all', 'the', 'thing']

# %%
strip_sentence="  Is this using in function for doing some program and all the thing "
new_sentence=strip_sentence[::-1]
print(new_sentence)
# Out:
#  gniht eht lla dna margorp emos gniod rof noitcnuf ni gnisu siht sI

# %%
practice="Making a time table to practice dialy"
maintain=
# Out:
#   Cell In[44], line 2
#     maintain=
#              ^
# SyntaxError: invalid syntax

# %%
meta_list = [1, 2, [3, 4, [5, 6, 7]]]
meta_list[2][2][1]
# Out:
# 6

# %%
meta_list[1]
# Out:
# 2

# %%
meta_list=[10,20,30]
print(meta_list)
meta_list.append([1])
# Out:
# [10, 20, 30]

# %%
course_list=['Data Science', 'Data Engineering', 'Azure DevOps']

# %%
#course_list.append("data science")
course_list
# Out:
# ['Data Science', 'Data Engineering', 'Azure DevOps', 'data science']

# %%
course_list.append("python basic")

# %%
course_list
# Out:
# ['Data Science',
#  'Data Engineering',
#  'Azure DevOps',
#  'data science',
#  'python basic']

# %%
course_list.insert(3,"machine learning")

# %%
course_list
# Out:
# ['Data Science',
#  'Data Engineering',
#  'Azure DevOps',
#  'machine learning',
#  'data science',
#  'python basic']

# %%
course_list.remove("data science")

# %%
course_list
# Out:
# ['Data Science',
#  'Data Engineering',
#  'Azure DevOps',
#  'machine learning',
#  'python basic']

# %%
enrolements=[250,350,380,470,520]

# %%
enrolements
# Out:
# [250, 350, 380, 470, 520]

# %%
enrolements[3:]
# Out:
# [470, 520]

# %%
enrolements.append[400,200]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 enrolements.append[400,200]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
name="learn the python and the to do practice and the consistency then only you reach goal"
new_line=name.split(" ")
new_line
# Out:
# ['learn',
#  'the',
#  'python',
#  'and',
#  'the',
#  'to',
#  'do',
#  'practice',
#  'and',
#  'the',
#  'consistency',
#  'then',
#  'only',
#  'you',
#  'reach',
#  'goal']

# %%
new_line[1:5]
# Out:
# ['the', 'python', 'and', 'the']

# %%
list=[80,120,160,200,240,280,320]
list[0:1]
# Out:
# [80]

# %%
list[5::-1]
# Out:
# [280, 240, 200, 160, 120, 80]

# %%
list[::2]
# Out:
# [80, 160, 240, 320]

# %%
shop_lists=['sugar','Atta','tea powder','chilli powder','green chilli','tamota"s']

# %%
shop_lists.append("potatos")

# %%
shop_lists
# Out:
# ['sugar',
#  'Atta',
#  'tea powder',
#  'chilli powder',
#  'green chilli',
#  'tamota"s',
#  'potatos']

# %%
shop_lists.append(["masala powder",'black seeds'])

# %%
shop_lists
# Out:
# ['sugar',
#  'Atta',
#  'tea powder',
#  'chilli powder',
#  'green chilli',
#  'tamota"s',
#  'potatos',
#  ['masala powder', 'black seeds']]

# %%
kids=["chocolates","bickets","ice creams","chips"]

# %%
kids.extend(["chacoes","good day","chakes"])

# %%
kids
# Out:
# ['chocolates',
#  'bickets',
#  'ice creams',
#  'chips',
#  'chacoes',
#  'good day',
#  'chakes']

# %%
lists_char=['a','b','c']

# %%
lists_char.extend('efgh')

# %%
lists_char
# Out:
# ['a', 'b', 'c', 'e', 'f', 'g', 'h']

# %%
len(lists_char)
# Out:
# 7

# %%
lists_char[6]
# Out:
# 'h'

# %%
dictionary={}
type(dictionary)
# Out:
# dict

# %%
empty_set=set()
type(empty_set)
# Out:
# set

# %%
student={
    "name":"lohit",
    "age":45,
    "grade":"A"
}
print(student)
# Out:
# {'name': 'lohit', 'age': 45, 'grade': 'A'}

# %%
student={
    "name":"Aravind",
    "Age":25,
    "name":"uday Pakash"
    }
print(student)
# Out:
# {'name': 'uday Pakash', 'Age': 25}

# %%
valid_dict={
    "name":"Aravind",
    42:"number",
    (1,2):"tuple",
    True:"Boolean"
}

# %%
valid_dict
# Out:
# {'name': 'Aravind', 42: 'number', (1, 2): 'tuple', True: 'Boolean'}

# %%
invalid_dict={
    [1,2]:"list"
}

# %%
flexible_dict={
    "name":"Aravind",
    "age":45,
    44:"sai sneha",
    "hobbies":["reading","dancing","watching"],
    "address":{
        "Village":"Uppara palli",
        "city":"Ananatapur",
        "pincode":515002
    }
}

# %%
flexible_dict
# Out:
# {'name': 'Aravind',
#  'age': 45,
#  44: 'sai sneha',
#  'hobbies': ['reading', 'dancing', 'watching'],
#  'address': {'Village': 'Uppara palli',
#   'city': 'Ananatapur',
#   'pincode': 515002}}

# %%
learning={
    "Data Science":["python","pandas","ML"],
    "Data Engineering":["Adf","ADLS","Databricks"],
}
student={"Alice":4.5,"bob":4.8}

# %%
learning
# Out:
# {'Data Science': ['python', 'pandas', 'ML'],
#  'Data Engineering': ['Adf', 'ADLS', 'Databricks']}

# %%
ds_science=learning["Data Science"]
print(ds_science)
# Out:
# ['python', 'pandas', 'ML']

# %%
cloud_tools=learning["cloud computing"]
cloud_tools
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 cloud_tools=learning["cloud computing"]
#       2 cloud_tools
#
# KeyError: 'cloud computing'

# %%
ds_tools=learning["Data Engineering"]
ds_tools
# Out:
# ['Adf', 'ADLS', 'Databricks']

# %%
ml_tools=learning.get("Machine Learning",200)
ml_tools
# Out:
# 200

# %%
learning
# Out:
# {'Data Science': ['python', 'pandas', 'ML'],
#  'Data Engineering': ['Adf', 'ADLS', 'Databricks']}

# %%
learning["Azure DevOps"]=[{"GitHub","pipelines","terrafrom"}]

# %%
learning
# Out:
# {'Data Science': ['python', 'pandas', 'ML'],
#  'Data Engineering': ['Adf', 'ADLS', 'Databricks'],
#  'Azure DevOps': [{'GitHub', 'pipelines', 'terrafrom'}]}

# %%
learning["Data Science"]=['python', 'pandas', 'ML','visualization']

# %%
learning["Data Science"]
# Out:
# ['python', 'pandas', 'ML', 'visualization']

# %%
learning["learning"]=[]

# %%
learning
# Out:
# {'Data Science': ['python', 'pandas', 'ML', 'visualization'],
#  'Data Engineering': ['Adf', 'ADLS', 'Databricks'],
#  'Azure DevOps': [{'GitHub', 'pipelines', 'terrafrom'}],
#  'learning': []}

# %%
ds_tools=learning["Data Science"]
ds_tools
# Out:
# ['python', 'pandas', 'ML', 'visualization']

# %%
student
# Out:
# {'Alice': 4.5, 'bob': 4.8}

# %%
student_ratings = {"Alice": 4.5, "Bob": 4.8}

# %%
student_ratings
# Out:
# {'Alice': 4.5, 'Bob': 4.8}

# %%
student_ratings["Bob"]={2}

# %%
student_ratings
# Out:
# {'Alice': 4.5, 'Bob': {2}}

# %%
type(student_ratings["Bob"])
# Out:
# set

# %%
learning
# Out:
# {'Data Science': ['python', 'pandas', 'ML', 'visualization'],
#  'Data Engineering': ['Adf', 'ADLS', 'Databricks'],
#  'Azure DevOps': [{'GitHub', 'pipelines', 'terrafrom'}],
#  'learning': []}

# %%
ds_tools=learning.pop("Data Engineering")

# %%
ds_tools
# Out:
# ['Adf', 'ADLS', 'Databricks']

# %%
learning
# Out:
# {'Data Science': ['python', 'pandas', 'ML', 'visualization'],
#  'Azure DevOps': [{'GitHub', 'pipelines', 'terrafrom'}],
#  'learning': []}

# %%
ds_Science=learning.pop("Data Science")
ds_science
# Out:
# ['python', 'pandas', 'ML']

# %%
learning
# Out:
# {'Azure DevOps': [{'GitHub', 'pipelines', 'terrafrom'}], 'learning': []}

# %%
cloud_tools=learning.pop("Cloud Computing","Path NOt found")
cloud_tools
# Out:
# 'Path NOt found'

# %%
learning
# Out:
# {'Azure DevOps': [{'GitHub', 'pipelines', 'terrafrom'}], 'learning': []}

# %%
learning_paths = {
    "Data Science": ["Python", "Pandas", "ML"],
    "Data Engineering": ["ADF", "ADLS", "Databricks"],
    "Azure DevOps": ["GitHub", "Pipelines", "Terraform"] 
}

# %%
learning_paths
# Out:
# {'Data Science': ['Python', 'Pandas', 'ML'],
#  'Data Engineering': ['ADF', 'ADLS', 'Databricks'],
#  'Azure DevOps': ['GitHub', 'Pipelines', 'Terraform']}

# %%
leaning_tools=learning_paths.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 leaning_tools=learning_paths.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
ds_tools=learning_paths.pop("Data Engineering")
ds_tools
# Out:
# ['ADF', 'ADLS', 'Databricks']

# %%
learning_paths.popitem()
# Out:
# ('Azure DevOps', ['GitHub', 'Pipelines', 'Terraform'])

# %%
learning_paths
# Out:
# {'Data Science': ['Python', 'Pandas', 'ML']}

# %%
learning_paths["Azure DevOps"]=['GitHub', 'Pipelines', 'Terraform']

# %%
learning_paths["Data Engineering"]=["ADF", "ADLS", "Databricks"]

# %%
learning_paths
# Out:
# {'Data Science': ['Python', 'Pandas', 'ML'],
#  'Azure DevOps': ['GitHub', 'Pipelines', 'Terraform'],
#  'Data Engineering': ['ADF', 'ADLS', 'Databricks']}

# %%
ds_tools=learning_paths.pop("Data Science")
ds_tools
# Out:
# ['Python', 'Pandas', 'ML']

# %%
("Lohit", 50, "Bangalore")
# Out:
# ('Lohit', 50, 'Bangalore')

# %%
City,teaching,name,age=("lohit",50,"Bangalore","python")

# %%
name
# Out:
# 'Bangalore'

# %%
key, value = ('Azure DevOps', ['GitHub', 'Pipelines', 'Terraform'])

# %%
key
# Out:
# 'Azure DevOps'

# %%
value
# Out:
# ['GitHub', 'Pipelines', 'Terraform']

# %%
learning_paths
# Out:
# {'Azure DevOps': ['GitHub', 'Pipelines', 'Terraform'],
#  'Data Engineering': ['ADF', 'ADLS', 'Databricks']}

# %%
Hello,hi,how=("Sneha","Mom","Dad")

# %%
Hello
# Out:
# 'Sneha'

# %%
number_dict={1:'a',2:'b',3:'c'}

# %%
k,v=number_dict.popitem()

# %%
print(v)
# Out:
# c

# %%
print(k)
# Out:
# 3

# %%
path_keys=learning_paths.items()

# %%
path_keys
# Out:
# dict_items([('Azure DevOps', ['GitHub', 'Pipelines', 'Terraform']), ('Data Engineering', ['ADF', 'ADLS', 'Databricks'])])

# %%
path_list_keys=list(path_keys)

# %%
key1,values1=path_list_keys[0]

# %%
key1
# Out:
# 'Azure DevOps'

# %%
values1
# Out:
# ['GitHub', 'Pipelines', 'Terraform']

# %%
path_list_keys[1]
# Out:
# ('Data Engineering', ['ADF', 'ADLS', 'Databricks'])

# %%
keys2,values2=path_list_keys[1]

# %%
keys2
# Out:
# 'Data Engineering'

# %%
tech_skills=("Python","SQL","GIT","CI/CD","Python")
course_info=("DS101","Data Science",15,4.8)

# %%
tech_skills[2]
# Out:
# 'GIT'

# %%
tech_skills[-1]
# Out:
# 'Python'

# %%
tech_skills[:2]
# Out:
# ('Python', 'SQL')

# %%
tech_skills[-2]
# Out:
# 'CI/CD'

# %%
empty_tuple=()

# %%
empty_tuple.extend(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 empty_tuple.extend(10)
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
tech_skills=("Python","SQL","GIT","CI/CD","Python","SQL","Python")
rating=(5,4,5,6,7,8,9)

# %%
python_count=tech_skills.count("Python")
python_count
# Out:
# 3

# %%
sql_count=tech_skills.count("SQL")
sql_count
# Out:
# 2

# %%
tuple_created=(1,2,3,4,5,)

# %%
type(tuple_created)
# Out:
# tuple

# %%
converted_to_lists=list(tuple_created)

# %%
type(converted_to_lists)
# Out:
# list

# %%
unique_chars=set("Edukron Institute")
print(f" unique chars in eduron :{unique_chars}")
# Out:
#  unique chars in eduron :{'o', 't', 'r', 'u', 's', 'e', 'd', ' ', 'k', 'n', 'I', 'E', 'i'}

# %%
#print the length of string
name=input("enter the self intro")
len(name)
# Out:
# 7

# %%
#covert the string to "lower" and "upper"
course="Python and Sql and Data Sciene"
print(course.upper())
print(course.lower())

# %%
#palindrome
course_slogan="Engineering"
course=course_slogan[::-1]
course=course_slogan
print(course)
# Out:
# Engineering

# %%
#count of the words
slogan="learn data engineering with real-time project"
new_word=slogan.split()
print(len(new_word))
# Out:
# 6

# %%
#replace with spaces to "_"
slogan="learn data engineering with real-time project"
new_sentence=slogan.replace(" ","_")
print(new_sentence)
# Out:
# learn_data_engineering_with_real-time_project

# %%
details="new languages learning overhere"
new_word=details[::-1]
print(new_word)
# Out:
# erehrevo gninrael segaugnal wen

# %%
name=" sentence "
remove_spaces=name.strip()
print(remove_spaces)
# Out:
# sentence

# %%
details="new languages learning overhere"
start_word=details.startswith("n")
start_word
# Out:
# True

# %%
languages="some many languages is their like java and python and c and c++"
new_languages=languages.count("and")
print(new_languages)
# Out:
# 3

# %%
strip_sentence="  Is this using in function for doing some program and all the thing "
new_split=strip_sentence.rsplit()
print(new_split)
# Out:
# ['Is', 'this', 'using', 'in', 'function', 'for', 'doing', 'some', 'program', 'and', 'all', 'the', 'thing']

# %%
list=['Is', 'this', 'using', 'in', 'function', 'for', 'doing', 'some', 'program', 'and', 'all', 'the', 'thing']
sentence =" ".join(list)
print(sentence)
# Out:
# Is this using in function for doing some program and all the thing

# %%
name="my is a aravind, i am from anantapur,i am coming from andhra pradesh"
new_sentence=name.replace("i am coming from"," coming")
print(new_sentence)
# Out:
# my is a aravind, i am from anantapur, coming andhra pradesh

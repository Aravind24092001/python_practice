# %%
institute="edukron"
focus_area="Data science"
full_title=institute+": "+focus_area
print(f"1. full title: {full_title}")
# Out:
# 1. full title: edukron: Data science

# %%
print(full_title)
# Out:
# edukron: Data science

# %%
course_name="Azure DevOps"
welcome_message="welcome to "+institute+"' s "+course_name+" course!"
print(f"2. Welcome message: {welcome_message}")
# Out:
# 2. Welcome message: welcome to edukron' s Azure DevOps course!

# %%
keyword="python "
emphasized=keyword*3
print(f"4. Emphasized keyword: {emphasized}")
# Out:
# 4. Emphasized keyword: python python python

# %%
separator="-*="*10
print(f"3.separator: {separator}")
# Out:
# 3.separator: -*=-*=-*=-*=-*=-*=-*=-*=-*=-*=

# %%
separator = "-*=" * 10
print(f"3. Separator: {separator}")
# Out:
# 3. Separator: -*=-*=-*=-*=-*=-*=-*=-*=-*=-*=

# %%
base_path="/courses/"
course_id="DA101"
full_path=base_path+course_id
print(f"3. simple path :{full_path}")
# Out:
# 3. simple path :/courses/DA101

# %%
student_name="Alex"
username_suffix="@edukron.com"
email=student_name+username_suffix
print(f"7.student email:{email}")
# Out:
# 7.student email:Alex@edukron.com

# %%
heading="course Modules"
underline="="*len(heading)
print(f"5.Heading:\n{heading}\n{underline}")
# Out:
# 5.Heading:
# course Modules
# ...

# %%
name="Aravind"
highliting="="*len(name)
print(f"highliting the name: \n{name}\n{highliting}")
# Out:
# highliting the name:
# Aravind
# ...

# %%
institute="edukron"
course_slogan="learn Data engineering with real projects"
tech_stack="Azure DeveOps and python"

# %%
name_length=len(institute)
print(f"1.length of'{institute}': {name_length}")
# Out:
# 1.length of'edukron': 7

# %%
institute="edukron"
course_slogan="learn Data engineering with real projects"
tech_stack="Azure DeveOps and python"

# %%
frist_char=institute[0]
print(f"1.frist character of'{institute}': {frist_char}")
# Out:
# 1.frist character of'edukron': e

# %%
last_char=institute[-1]
print(f"2.last character'{institute}': \n{last_char}")
# Out:
# 2.last character'edukron':
# n

# %%
frist_5=tech_stack[:5]
print(f"1.frist 5 character of char_tech:'{frist_5}'")
# Out:
# 1.frist 5 character of char_tech:'Azure'

# %%
institute="edukron"
course_slogan="learn Data engineering with real projects"
tech_stack="Azure DeveOps and python"

# %%
middle_word=tech_stack[6:13]
print(f"3.middle of word:'{middle_word}'")
# Out:
# 3.middle of word:'DeveOps'

# %%
combined="tech_stack 's printing "+frist_5+" "+middle_word
print(f"4.combined of the {tech_stack} from {combined}")
# Out:
# 4.combined of the Azure DeveOps and python from tech_stack 's printing Azure DeveOps

# %%
course_list=["Data Science","Data Enigeering","Azure DeveOps","Python Basics","Sql Fundamentals"]
Student_counts=[350,420,380,500,450]

# %%
print(f"1. course Lists:{course_list}")
# Out:
# 1. course Lists:['Data Science', 'Data Enigeering', 'Azure DeveOps', 'Python Basics', 'Sql Fundamentals']

# %%
frist_course=course_list[0]
print(f"2. first course: {frist_course}")
# Out:
# 2. first course: Data Science

# %%
last_count=Student_counts[-1]
print(f"3.last course count:{last_count}")
# Out:
# 3.last course count:450

# %%
every_second_course=course_list[::2]
print(f"5. Every second element{every_second_course}")
# Out:
# 5. Every second element['Data Science', 'Azure DeveOps', 'Sql Fundamentals']

# %%
course_list=["Data Science","Data engineering","Azure DeveOps"]
new_enrollments=[15,20,10]

# %%
course_list.append("cloud computing")
print(f"lst after appending course:\n{course_list}")
# Out:
# lst after appending course:
# ['Data Science', 'Data engineering', 'Azure DeveOps', 'cloud computing', 'cloud computing']

# %%
new_enrollments.append(18)
print(f"3.enrollments after apppend{new_enrollments}")
# Out:
# 3.enrollments after apppend[15, 20, 10, 18]

# %%
meta_list=[1,2]
meta_list.append([3,4])
print(f"list after appending a list {meta_list}")
# Out:
# list after appending a list [1, 2, [3, 4]]

# %%
batch_students=["Alice","Bob"]

# %%
batch_students.append("charlie")
print(f"5.Batch students after append: {batch_students}")
# Out:
# 5.Batch students after append: ['Alice', 'Bob', 'charlie']

# %%
course_lists=['Data Science', 'Data Enigeering', 'Azure DeveOps', 'Python Basics', 'Sql Fundamentals']
data_Science=["DS Intro","Pythn for DS"]
new_tools=("Docker","Kubernets")

# %%
data_Science.extend(course_lists)
print(f"1. extends course lists{course_lists}")
# Out:
# 1. extends course lists['Data Science', 'Data Enigeering', 'Azure DeveOps', 'Python Basics', 'Sql Fundamentals']

# %%
meta_lists=[2,3,4,5,[5,6,[8,7,9]]]
new_lists=meta_lists[-1][-3]
new_lists
# Out:
# 5

# %%
meta_list=[3,[3,4],5,6,7]
new_line=meta_list[1][1]
new_line
# Out:
# 4

# %%
meta_list=[0,1]
meta_list.append((2, "ram",3 ,4))
meta_list
# Out:
# [0, 1, (2, 'ram', 3, 4)]

# %%
data_science_course=["Ds Intro","python for DS"]
data_eng_course=["DE Intro","SQl for DE","AdF"]
new_toolss=["docker","Kubernets"]

# %%
data_science_course.extend(data_eng_course)
print(data_science_course)
# Out:
# ['Ds Intro', 'python for DS', 'DE Intro', 'SQl for DE', 'AdF']

# %%
data_science_course[3]
# Out:
# 'SQl for DE'

# %%
all_tools=["python","Sql"]
all_tools.extend(new_toolss)
all_tools
# Out:
# ['python', 'Sql', 'docker', 'Kubernets']

# %%
letters=['a','b']
letters.append("cde")
letters
# Out:
# ['a', 'b', 'cde']

# %%
data_science_course=["Ds Intro","python for DS"]
data_science_course.extend(("python basics"))
print(data_science_course)
# Out:
# ['Ds Intro', 'python for DS', 'p', 'y', 't', 'h', 'o', 'n', ' ', 'b', 'a', 's', 'i', 'c', 's']

# %%
empty_list=[]
empty_list.extend([1,2,3])
print(empty_list)
# Out:
# [1, 2, 3]

# %%
topics=["visualization"]
data_analytics_topics={"power BI","EDA","reporting"}
topics.extend(data_analytics_topics)
print(topics)
# Out:
# ['visualization', 'reporting', 'EDA', 'power BI']

# %%
numbers=[1,2,3,4,5]
numbers.insert(-1,6)
print(numbers)
# Out:
# [1, 2, 3, 4, 6, 5]

# %%
tasks=["Task A", "Tasks B"]
tasks.insert(len(tasks), "Tasks C")
print(tasks)
# Out:
# ['Task A', 'Tasks B', 'Tasks C']

# %%
modules=["M1","M2"]
modules.insert(-0,"M3")
print(modules)
len(modules)
# Out:
# ['M3', 'M1', 'M2']
# 3

# %%
course_lists=["python Basics","Data Science","cloud Intro","Data Engineering","Data Science"]
tools=["python","SQL","Git","sql"]

# %%
course_lists.remove("cloud Intro")
print(course_lists)
# Out:
# ['python Basics', 'Data Science', 'Data Engineering', 'Data Science']

# %%
course_lists.remove("Data Science")
print(course_lists)
# Out:
# ['python Basics', 'cloud Intro', 'Data Engineering', 'Data Science']

# %%
try:
    tools.remove("java")
except ValueError as e:
    print(f",5.error removing : {e}")
# Out:
# ,5.error removing : list.remove(x): x not in list

# %%
course_lists.remove("aravind")
print(course_lists)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 course_lists.remove("aravind")
#       2 print(course_lists)
#
# ValueError: list.remove(x): x not in list

# %%
course_list = ["Python Basics", "Data Science", "Data Engineering"]
tasks = ["Review Code", "Update Docs", "Deploy"]

# %%
last_course=course_list.pop()
print(f" last pop:'{last_course}' , list is now{course_list}")
# Out:
#  last pop:'Data Engineering' , list is now['Python Basics', 'Data Science']

# %%
frist_course=course_list.pop(0)
print(f" poped first course:'{frist_course}' list is now{course_list}")
# Out:
#  poped first course:'Python Basics' list is now['Data Science']

# %%
course_list = ["Data Engineering", "Azure DevOps", "Data Science", "Python Basics"]
student_counts = [350, 420, 380, 500, 450]
mixed_case_courses = ["azure DevOps", "Python basics", "Data science"]

# %%
course_list.sort()
print(f"1.sorted courses{course_list}")
# Out:
# 1.sorted courses['Azure DevOps', 'Data Engineering', 'Data Science', 'Python Basics']
